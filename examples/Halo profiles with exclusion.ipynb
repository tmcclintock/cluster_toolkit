# %%
import cluster_toolkit as ct
from cluster_toolkit import exclusion as ex
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
r = np.logspace(-2, 2)
rt = 2 #Mpc/h
beta = 1 #Mpc/h
theta = ex.theta_at_r(r, rt, beta)
plt.plot(r,theta)
plt.xscale('log')
plt.xlabel("r [Mpc/h]")
plt.ylabel(r"$\theta(r,r_t,\beta)$")
# Out:
# Text(0,0.5,'$\\theta(r,r_t,\\beta)$')
